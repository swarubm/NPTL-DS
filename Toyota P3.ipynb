# %%
import numpy as np
import pandas as pd

# %%
car_data = pd.read_csv("/content/Toyota.csv",index_col=0,na_values=["??","????"])

# %%
car_data["MetColor"] = car_data["MetColor"].astype("object")
car_data["Automatic"] = car_data["Automatic"].astype("object")

# %%
car_data["FuelType"].nbytes
# Out:
# 11488

# %%
car_data["FuelType"].astype('category').nbytes
# Out:
# 1460

# %%
car_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1436 entries, 0 to 1435
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Price      1436 non-null   int64
#  1   Age        1336 non-null   float64
#  2   KM         1421 non-null   float64
#  3   FuelType   1336 non-null   object
#  4   HP         1430 non-null   float64
#  5   MetColor   1286 non-null   object
#  6   Automatic  1436 non-null   object
#  7   CC         1436 non-null   int64
#  8   Doors      1436 non-null   object
#  9   Weight     1436 non-null   int64
# dtypes: float64(3), int64(3), object(4)
# memory usage: 123.4+ KB

# %%
np.unique(car_data['Doors'])
# Out:
# array(['2', '3', '4', '5', 'five', 'four', 'three'], dtype=object)

# %%
car_data.replace('five','5',inplace=True)
car_data.replace('four','4',inplace=True)
car_data.replace('three','3',inplace=True)

# %%
np.unique(car_data['Doors'])
# Out:
# array(['2', '3', '4', '5'], dtype=object)

# %% [markdown]
# # converting obj to int

# %%
car_data['Doors'] =car_data['Doors'].astype('int64')

# %%
car_data.isnull().sum()
# Out:
# Price          0
# Age          100
# KM            15
# FuelType     100
# HP             6
# MetColor     150
# Automatic      0
# CC             0
# Doors          0
# Weight         0
# dtype: int64
