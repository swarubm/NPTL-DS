# %% [markdown]
# <a href="https://colab.research.google.com/github/swarubm/NPTL-DS/blob/main/Toyota_2/2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cars_data = pd.read_csv('/content/Toyota.csv',index_col=0,na_values=["??","????"])

# %% [markdown]
# # we should remove all missing values

# %%
cars_data.dropna(axis=0,inplace=True)

# %% [markdown]
# #1  scatter plot

# %%
sns.set(style="darkgrid")
sns.regplot(x=cars_data['Age'],y=cars_data['Price'])     #default fit reg = true in this line thats why the line will appear on the plot
# Out:
# <Axes: xlabel='Age', ylabel='Price'>

# %%
sns.set(style="darkgrid")
sns.regplot(x=cars_data['Age'],
            y=cars_data['Price']
            ,fit_reg=False)     #default fit reg = true in this line thats why the line will appear on the plot
# Out:
# <Axes: xlabel='Age', ylabel='Price'>

# %% [markdown]
# we can add the different marker

# %%
sns.set(style="darkgrid")
sns.regplot(x=cars_data['Age'],
            y=cars_data['Price']
            ,marker="*",fit_reg=False)
# Out:
# <Axes: xlabel='Age', ylabel='Price'>

# %%
sns.lmplot(x='Age',
            y='Price',
            data=cars_data,
            fit_reg=False,
           hue='FuelType',
           legend=True,
           palette="Set1")

# %% [markdown]
# # Histogram

# %%
sns.distplot(cars_data['Age'])
# Out:
# /tmp/ipython-input-384205204.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(cars_data['Age'])
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.distplot(cars_data['Age'],kde = False)  #kde is outline
# Out:
# /tmp/ipython-input-1554443826.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(cars_data['Age'],kde = False)  #kde is outline
# <Axes: xlabel='Age'>

# %%
sns.distplot(cars_data['Age'],kde = False,bins=5)#we can change the bins
# Out:
# /tmp/ipython-input-4146409268.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(cars_data['Age'],kde = False,bins=5)#we can change the bins
# <Axes: xlabel='Age'>

# %% [markdown]
# # Bar plot

# %%
sns.countplot(x="FuelType",data = cars_data)
# Out:
# <Axes: xlabel='FuelType', ylabel='count'>

# %%
sns.countplot(x="FuelType",data = cars_data,hue = "Automatic")
# Out:
# <Axes: xlabel='FuelType', ylabel='count'>

# %% [markdown]
# ## Box and whiskers plot

# %%
sns.boxplot(y=cars_data["Price"])
# Out:
# <Axes: ylabel='Price'>

# %% [markdown]
# by the graph  we can say that around 20k is the highest price
#
#
# 2 the data which are outside the whiskers  are the outliers
#
# 3 q1,q2,q3 insights

# %% [markdown]
# we can use this when we are comparing numerical vs categorical variable

# %%
sns.boxplot(x=cars_data['FuelType'], y=cars_data["Price"])
# Out:
# <Axes: xlabel='FuelType', ylabel='Price'>

# %%
sns.boxplot(x=cars_data['FuelType'], y=cars_data["Price"],hue=cars_data['Automatic'],data=cars_data)
# Out:
# <Axes: xlabel='FuelType', ylabel='Price'>

# %% [markdown]
# # split the plotting window

# %%
f,(ax_box,ax_hist)=plt.subplots(2,gridspec_kw={"height_ratios":(.25,.75)})

# %%
sns.boxplot(cars_data['Price'],ax=ax_box)
sns.distplot(cars_data['Price'],ax=ax_hist,kde = False)
# Out:
# /tmp/ipython-input-2038677720.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(cars_data['Price'],ax=ax_hist,kde = False)
# <Axes: xlabel='Price'>

# %%
sns.boxplot(cars_data['Price'],ax=ax_box)
sns.displot(cars_data['Price'],ax=ax_hist,kde = False)
# Out:
# /usr/local/lib/python3.12/dist-packages/seaborn/distributions.py:2125: UserWarning: `displot` is a figure-level function and does not accept the ax= parameter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.pairplot(cars_data,kind="scatter",hue = "FuelType")
